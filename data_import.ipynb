# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
path="/home/stan/Documents/dev/psignal/Data/"
pureTwt='twitter_noretweets_daily.csv'

sym_file="symbology.csv"
reTwt='twitter_withretweets_daily.csv'
stockTwt='stocktwits_daily.csv'
#path="C:\\Users\\stan\\Google Drive\\MSc BA\\Courses\\Data Analytics\\Data\\"
#path="C:\\Dropbox\\Google\\MSc BA\\Courses\\Data Analytics\\Data\\"

# %%
sym=pd.read_csv(filepath_or_buffer=path+sym_file,delimiter=",",header=0)

# %%
ptwt=pd.read_csv(filepath_or_buffer=path+pureTwt,delimiter=",",header=0)

# %%
ptwt.head()
# Out:
#                SOURCE SYMBOL         TIMESTAMP_UTC  BULLISH_INTENSITY  \
# 0  twitter_noretweets  10GEN  2011-04-08T04:00:00Z                  0
# 1  twitter_noretweets  10GEN  2011-04-16T04:00:00Z                  0
# 2  twitter_noretweets  10GEN  2011-04-17T04:00:00Z                  0
# 3  twitter_noretweets  10GEN  2011-04-20T04:00:00Z                  0
# 4  twitter_noretweets  10GEN  2011-07-19T04:00:00Z                  0
#
#    BEARISH_INTENSITY  BULL_MINUS_BEAR  BULL_SCORED_MESSAGES  \
# 0                  0                0                     0
# 1                  0                0                     0
# 2                  0                0                     0
# 3                  0                0                     0
# 4                  0                0                     0
#
#    BEAR_SCORED_MESSAGES  BULL_BEAR_MSG_RATIO  TOTAL_SCANNED_MESSAGES
# 0                     0                    0                       2
# ...

# %%
ptwt.columns
# Out:
# Index([u'SOURCE', u'SYMBOL', u'TIMESTAMP_UTC', u'BULLISH_INTENSITY',
#        u'BEARISH_INTENSITY', u'BULL_MINUS_BEAR', u'BULL_SCORED_MESSAGES',
#        u'BEAR_SCORED_MESSAGES', u'BULL_BEAR_MSG_RATIO',
#        u'TOTAL_SCANNED_MESSAGES'],
#       dtype='object')

# %%
rtwt=pd.read_csv(filepath_or_buffer=path+reTwt,delimiter=",",header=0)

# %%
stwt=pd.read_csv(filepath_or_buffer=path+stockTwt,delimiter=",",header=0)

# %%
ptwt['TIMESTAMP_UTC']=pd.to_datetime(arg=ptwt.TIMESTAMP_UTC,infer_datetime_format='true')

# %%
#just reorders column positions and selects required data
cols=['SYMBOL','TIMESTAMP_UTC','BULLISH_INTENSITY','BEARISH_INTENSITY','BULL_SCORED_MESSAGES','BEAR_SCORED_MESSAGES']
mini_twt=ptwt.reindex(columns=cols)
mini_twt.columns=['sym','date','bull','bear','volbull','volbear']

# %%
mini_twt.head()
# Out:
#      sym                date  bull  bear  volbull  volbear
# 0  10GEN 2011-04-08 04:00:00     0     0        0        0
# 1  10GEN 2011-04-16 04:00:00     0     0        0        0
# 2  10GEN 2011-04-17 04:00:00     0     0        0        0
# 3  10GEN 2011-04-20 04:00:00     0     0        0        0
# 4  10GEN 2011-07-19 04:00:00     0     0        0        0

# %% [markdown]
# TIMESERIES GRAPH AVERAGE SENTIMENT

# %%
miss_bull=mini_twt['volbull']==0
mini_twt['bull'].loc[miss_bull]=np.nan
miss_bear=mini_twt['volbear']==0
mini_twt['bear'].loc[miss_bear]=np.nan
mini_twt.head(15)
# Out:
# /usr/share/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#       sym                date  bull  bear  volbull  volbear
# 0   10GEN 2011-04-08 04:00:00   NaN   NaN        0        0
# 1   10GEN 2011-04-16 04:00:00   NaN   NaN        0        0
# 2   10GEN 2011-04-17 04:00:00   NaN   NaN        0        0
# 3   10GEN 2011-04-20 04:00:00   NaN   NaN        0        0
# 4   10GEN 2011-07-19 04:00:00   NaN   NaN        0        0
# 5   10GEN 2011-07-20 04:00:00   NaN   NaN        0        0
# 6   10GEN 2011-07-21 04:00:00   NaN   NaN        0        0
# 7   10GEN 2011-07-23 04:00:00  2.00  2.83        1        1
# 8   10GEN 2011-07-24 04:00:00   NaN   NaN        0        0
# ...

# %%
rep=mini_twt.groupby('date').agg([np.mean,np.std])
rep
# Out:
#                          bull                bear              volbull  \
#                          mean       std      mean       std       mean
# date
# 2010-11-30 05:00:00  1.828013  0.676154  1.708788  0.667921   1.161667
# 2010-12-01 05:00:00  1.869415  0.631881  1.518793  0.800271   3.704949
# 2010-12-02 05:00:00  1.902514  0.541316  1.548227  0.789321   4.151811
# 2010-12-03 05:00:00  1.910382  0.561781  1.545553  0.791285   3.916424
# 2010-12-04 05:00:00  1.820223  0.662060  1.122195  0.783930   1.069862
# 2010-12-05 05:00:00  1.860965  0.640720  1.628170  0.772603   1.654179
# 2010-12-06 05:00:00  1.929745  0.585383  1.567400  0.761526   4.004569
# 2010-12-07 05:00:00  1.827272  0.649510  1.669866  0.755053   3.662105
# 2010-12-08 05:00:00  1.842855  0.612905  1.613210  0.767895   3.713946
# 2010-12-09 05:00:00  1.849789  0.612555  1.548542  0.796721   3.714353
# 2010-12-10 05:00:00  1.834312  0.629297  1.615820  0.812065   3.479691
# ...

# %%
plt.plot(rep.index,rep.bear['mean'],label='bearish',color='red')
plt.plot(rep.index,rep.bull['mean'],label='bullish',color='green')
plt.legend(loc='best')
plt.fill_between(rep.index, rep.bear['mean']-2*rep.bear['std'], rep.bear['mean']+2*rep.bear['std'], color='red', alpha=0.2)
plt.fill_between(rep.index, rep.bull['mean']-2*rep.bull['std'], rep.bull['mean']+2*rep.bull['std'], color='green', alpha=0.2)
plt.title('Time series of mean bearish and bullish sentiment with 95% CI')
plt.show()

# %% [markdown]
# THIS CREATES MULTIINDEX ON TIME AND SYMBOL

# %%
panel=panel.set_index(['SYMBOL','TIMESTAMP_UTC'])

# %%
panel
# Out:
#                             BULLISH_INTENSITY  BEARISH_INTENSITY
# SYMBOL TIMESTAMP_UTC
# 10GEN  2011-04-08 04:00:00               0.00               0.00
#        2011-04-16 04:00:00               0.00               0.00
#        2011-04-17 04:00:00               0.00               0.00
#        2011-04-20 04:00:00               0.00               0.00
#        2011-07-19 04:00:00               0.00               0.00
#        2011-07-20 04:00:00               0.00               0.00
#        2011-07-21 04:00:00               0.00               0.00
#        2011-07-23 04:00:00               2.00               2.83
#        2011-07-24 04:00:00               0.00               0.00
#        2011-07-25 04:00:00               0.00               0.00
#        2011-07-26 04:00:00               0.00               0.00
#        2011-07-28 04:00:00               0.00               0.00
#        2011-07-29 04:00:00               0.00               0.00
# ...

# %%
import quandl
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-ab7fa5ad38a5> in <module>()
# ----> 1 import quandl
#
# ImportError: No module named 'quandl'
